# %% [markdown]
# ## Make three panel figure showing kk, kg and ge as a function of theta_ej
#
# Can probably make it a six panel figure, where the top row shows the 3D profiles and bottom row shows the observable
