# %%
import sys, os
os.environ['XLA_PYTHON_CLIENT_MEM_FRACTION']='.95'
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
from jax.lib import xla_bridge
platform = xla_bridge.get_backend().platform
import jax
jax.config.update('jax_platform_name', platform)
jax.config.update("jax_enable_x64", True)
import jax
# Change the current working directory to the desired path
# os.chdir('/mnt/home/spandey/ceph/GODMAX/src/')
import pathlib
curr_path = pathlib.Path().absolute()
abs_path_data = os.path.abspath(curr_path / "../../data/") 
abs_path_src = os.path.abspath(curr_path / "../../src/") 
abs_path_results = os.path.abspath(curr_path / "../../results/") 
sys.path.append((curr_path))
sys.path.append((abs_path_data))
sys.path.append((abs_path_results))
sys.path.append(abs_path_src)

from jax import config
config.update("jax_enable_x64", True)
import scipy.interpolate as interp
import pickle as pk
import numpy as np
import jax.numpy as jnp
import colossus 
from jax import vmap, grad
import matplotlib.pyplot as pl
pl.rc('text', usetex=True)
# Palatino
pl.rc('font', family='DejaVu Sans')

# deproj = sys.argv[1]
# probe = sys.argv[2]
deproj = 'None'
probe = 'all'

# cosmo_params_dict = {'flat': True, 'H0': 70.0, 'Om0': 0.2793, 'Ob0': 0.0463, 'sigma8': 0.821, 'ns': 0.972, 'w0':-1.0}
# cosmo_params_dict = {'flat': True, 'H0': 67.2, 'Om0': 0.31, 'Ob0': 0.049, 'sigma8': 0.81, 'ns': 0.95, 'w0':-1.0}
cosmo_params_dict = {'flat': True, 'H0': 67.2, 'Om0': 0.29, 'Ob0': 0.049, 'sigma8': 0.783, 'ns': 0.95, 'w0':-1.0}
sim_params_dict = {}
sim_params_dict['nfw_trunc'] = True
sim_params_dict['gamma_rhogas'] = 2.0
sim_params_dict['delta_rhogas'] = 7.0
# sim_params_dict['theta_co'] = 0.01
# sim_params_dict['theta_ej'] = 1.0

sim_params_dict['theta_co_0'] = 0.1
sim_params_dict['log10_Mstar0_theta_co'] = 14.0
sim_params_dict['nu_theta_co_M'] = 0.0
sim_params_dict['nu_theta_co_z'] = 0.0

sim_params_dict['theta_ej_0'] = 2.75
sim_params_dict['log10_Mstar0_theta_ej'] = 14.0
sim_params_dict['nu_theta_ej_M'] = 0.0
sim_params_dict['nu_theta_ej_z'] = 0.0

sim_params_dict['log10_Mc0'] = 14.83
sim_params_dict['log10_Mstar0'] = 14.0
sim_params_dict['mu_beta'] = 0.21
sim_params_dict['nu_z'] = 0.0
sim_params_dict['nu_M'] = 0.0

sim_params_dict['eta_star'] = 0.3
sim_params_dict['eta_cga'] = 0.6


sim_params_dict['neg_bhse_plus_1'] = 0.833
sim_params_dict['A_starcga'] = 0.09
sim_params_dict['log10_M1_starcga'] = 11.4
sim_params_dict['epsilon_rt'] = 4.0


sim_params_dict['a_zeta'] = 0.3
sim_params_dict['n_zeta'] = 2
sim_params_dict['alpha_nt'] = 0.18
sim_params_dict['beta_nt'] = 0.5
sim_params_dict['n_nt'] = 0.3
sim_params_dict['cosmo'] = cosmo_params_dict


halo_params_dict = {}
halo_params_dict['rmin'], halo_params_dict['rmax'], halo_params_dict['nr'] = 5e-3, 12, 32
# halo_params_dict['zmin'], halo_params_dict['zmax'], halo_params_dict['nz'] = 0.001, 0.002, 2
# halo_params_dict['zmin'], halo_params_dict['zmax'], halo_params_dict['nz'] = 0.001, 1.0, 10
# halo_params_dict['z_array'] = np.array([1e-3, 0.5, 1.0])
# halo_params_dict['zmin'], halo_params_dict['zmax'], halo_params_dict['nz'] = 0.01, 3.0, 20
halo_params_dict['zmin'], halo_params_dict['zmax'], halo_params_dict['nz'] = 0.01, 3.0, 24
# halo_params_dict['z_array'] = np.array([1e-3])
# halo_params_dict['z_array'] = np.array([0.5])
# halo_params_dict['z_array'] = np.array([1.0])
# halo_params_dict['nz'] = len(halo_params_dict['z_array'])
# halo_params_dict['lg10_Mmin'], halo_params_dict['lg10_Mmax'], halo_params_dict['nM'] = 12.0, 15.5, 20
halo_params_dict['lg10_Mmin'], halo_params_dict['lg10_Mmax'], halo_params_dict['nM'] = 11.0, 16.0, 32
halo_params_dict['cmin'], halo_params_dict['cmax'], halo_params_dict['nc'] = 2, 9, 16

lmin = 1.0
lmax = 60000.0
fac = 1
dl_log_array = 0.23025851 / fac
# dl_log_array = 0.1
l_array_all = np.exp(np.arange(np.log(lmin), np.log(lmax), dl_log_array))
dl_array = l_array_all[1:] - l_array_all[:-1]
l_array_survey = (l_array_all[1:] + l_array_all[:-1]) / 2.
halo_params_dict['ell_array'] = jnp.array(l_array_survey)
halo_params_dict['nell'] = len(l_array_survey)
halo_params_dict['ellmin'] = l_array_survey[0]
halo_params_dict['ellmax'] = l_array_survey[-1]
# halo_params_dict['ellmin'], halo_params_dict['ellmax'], halo_params_dict['nell'] = 8, 2**14, 32
# try:
halo_params_dict['sig_logc_z_array'] = np.ones(halo_params_dict['nz']) * 0.05
halo_params_dict['mdef'] = '200c'
halo_params_dict['hmf_model'] = 'T10'
# halo_params_dict['conc_model'] = 'Diemer15'
halo_params_dict['conc_model'] = 'Duffy08'
halo_params_dict['do_corr_2h_mm'] = True

# halo_params_dict['do_corr_2h_mm'] = False

from astropy.io import fits
df = fits.open(os.path.abspath(abs_path_data + '/DESxACT/2pt_NG_final_2ptunblind_02_26_21_wnz_maglim_covupdate.fits'))
# df = fits.open('data/DESxACT/2pt_NG_final_2ptunblind_02_26_21_wnz_maglim_covupdate.fits') 
z_array = df['nz_source'].data['Z_MID']
nz_info_dict = {}
nz_info_dict['z_array'] = z_array
nz_info_dict['nbins'] = 4
nz_info_dict['nz0'] = np.maximum(df['nz_source'].data['BIN1'], 1e-4)
nz_info_dict['nz1'] = np.maximum(df['nz_source'].data['BIN2'], 1e-4)
nz_info_dict['nz2'] = np.maximum(df['nz_source'].data['BIN3'], 1e-4)
nz_info_dict['nz3'] = np.maximum(df['nz_source'].data['BIN4'], 1e-4)
# nz_info_dict['nz4'] = np.maximum(df['nz_source'].data['BIN5'], 1e-4)
analysis_dict = {}
analysis_dict['nz_info_dict'] = nz_info_dict
analysis_dict['do_sheary'] = True
analysis_dict['do_shear2pt'] = True
analysis_dict['do_yy'] = True

analysis_dict['fsky_yy'] = 0.1
analysis_dict['fsky_ky'] = 0.1
analysis_dict['fsky_kk'] = 0.1
analysis_dict['fac_ell_hres'] = fac

# df_data = fits.open('/mnt/home/spandey/ceph/GODMAX/data/DESxACT/2pt_NG_final_2ptunblind_02_26_21_wnz_maglim_covupdate.fits')
# df_data = fits.open('/mnt/home/spandey/ceph/GODMAX/data/DESxACT/2pt_NG_final_2ptunblind_02_26_21_wnz_maglim_covupdate.fits')
theta_data = df['xip'].data['ANG'][0:20]

# analysis_dict['ellmin_transf'], analysis_dict['ellmax_transf'], analysis_dict['nell_transf'] = 8, 2**15, 16384
analysis_dict['angles_data_array'] = jnp.array(theta_data)
analysis_dict['beam_fwhm_arcmin'] = 1.6
analysis_dict['want_like_diff'] = True
analysis_dict['calc_nfw_only'] = False
analysis_dict['conc_dep_model'] = False


analysis_dict['get_cov'] = True
# analysis_dict['stats_for_cov'] = ['ky']
analysis_dict['stats_for_cov'] = ['ky', 'kk']
analysis_dict['analysis_coords'] = 'real'
# l_array_survey = np.logspace(np.log10(lmin), np.log10(lmax), int((lmax-lmin)/dl_log_array)+1)
analysis_dict['l_array_survey'] = jnp.array(l_array_survey)
analysis_dict['dl_array_survey'] = jnp.array(dl_array)
# analysis_dict['yy_total_ell_fname'] = '/Users/shivam/Downloads/ACT_Cls/Cls_ilc_SZ_deproj_cib_cibdBeta_1.7_10.7_yy_apod10arcmin_21Mar24.txt'
# analysis_dict['yy_total_ell_fname'] = '/Users/shivam/Downloads/ACT_Cls/Cls_ilc_SZ_yy_apod10arcmin_21Mar24.txt'
analysis_dict['yy_total_ell_fname'] = os.path.abspath(abs_path_data + '/DESxACT/ACT_Cls/Cls_ilc_SZ_yy_apod10arcmin_21Mar24.txt')
# analysis_dict['sigma_epsilon_SN_bins'] = [0.2724, 0.2724, 0.2724, 0.2724]
# analysis_dict['neff_arcmin2_SN_bins'] = [1.7971, 1.5521, 1.5967, 1.0979]

analysis_dict['sigma_epsilon_SN_bins'] = [0.243, 0.262, 0.259, 0.301]
analysis_dict['neff_arcmin2_SN_bins'] = [1.476, 1.479, 1.484, 1.461]

other_params_dict = {}
other_params_dict['A_IA'] = 0.0
other_params_dict['eta_IA'] = 0.0
other_params_dict['z0_IA'] = 0.62
other_params_dict['C1_rhocrit'] = 0.0134
other_params_dict['Delta_z_bias_array'] = np.zeros(nz_info_dict['nbins'])
other_params_dict['mult_shear_bias_array'] = np.zeros(nz_info_dict['nbins'])



if deproj == 'None':
    true_y_file = 'ilc_SZ_yy'
if deproj == 'cib_1p0':
    true_y_file = 'ilc_SZ_deproj_cib_1.0_10.7_yy'
if deproj == 'cib_1p2':
    true_y_file = 'ilc_SZ_deproj_cib_1.2_10.7_yy'        
if deproj == 'cib_1p4':
    true_y_file = 'ilc_SZ_deproj_cib_1.4_10.7_yy'        
if deproj == 'cib_1p6':
    true_y_file = 'ilc_SZ_deproj_cib_1.6_10.7_yy'  
if deproj == 'cib_1p7':
    true_y_file = 'ilc_SZ_deproj_cib_1.7_10.7_yy'                                      
if deproj == 'cib_1p8':
    true_y_file = 'ilc_SZ_deproj_cib_1.8_10.7_yy'        
if deproj == 'cib_2p0':
    true_y_file = 'ilc_SZ_deproj_cib_2.0_10.7_yy'                
if deproj == 'cib_1p0_dBeta':
    true_y_file = 'ilc_SZ_deproj_cib_cibdBeta_1.0_10.7_yy'        
if deproj == 'cib_1p2_dBeta':
    true_y_file = 'ilc_SZ_deproj_cib_cibdBeta_1.2_10.7_yy'
if deproj == 'cib_1p4_dBeta':
    true_y_file = 'ilc_SZ_deproj_cib_cibdBeta_1.4_10.7_yy'
if deproj == 'cib_1p6_dBeta':
    true_y_file = 'ilc_SZ_deproj_cib_cibdBeta_1.6_10.7_yy' 
if deproj == 'cib_1p7_dBeta':
    true_y_file = 'ilc_SZ_deproj_cib_cibdBeta_1.7_10.7_yy'  
if deproj == 'cib_1p8_dBeta':
    true_y_file = 'ilc_SZ_deproj_cib_cibdBeta_1.8_10.7_yy'         
if deproj == 'cib_2p0_dBeta':
    true_y_file = 'ilc_SZ_deproj_cib_cibdBeta_2.0_10.7_yy' 

save_DV_dir = os.path.abspath(abs_path_data + '/DESxACT/DV/')
# df_measure = pk.load(open('/mnt/home/spandey/ceph/GODMAX/data/DESxACT/DESxACT_gty_xip_xim_DV_ilc_SZ_yy.pk', 'rb'))
df_measure = pk.load(open(f'{save_DV_dir}/DESxACT_gty_xip_xim_DV_{true_y_file}.pk', 'rb'))
cov_total = df_measure['cov_total']
xi_all = df_measure['xi_all']
cov_total = jnp.array(cov_total)
data_vec = jnp.array(xi_all)

# probe = 'xip_xim' 
# probe = 'gty'
# probe = 'all'

if probe == 'xip_xim':
    cov_total = cov_total[80:, 80:]
    data_vec = data_vec[80:]
elif probe == 'gty':
    cov_total = cov_total[:80, :80]
    data_vec = data_vec[:80]

P_total = jnp.linalg.inv(cov_total)

from numpyro.distributions.transforms import AffineTransform
import numpyro.distributions as dist
import numpyro
def Uniform(name, min_value, max_value):
    """ Creates a Uniform distribution in target range from a base
    distribution between [-3, 3]
    """
    s = (max_value - min_value) / 6.
    return numpyro.sample(
            name,
            dist.TransformedDistribution(
                dist.Uniform(-3., 3.),
                AffineTransform(min_value + 3.*s, s),
            ),
        )

df_cs = fits.open(os.path.abspath(abs_path_data + '/DESxACT/2pt_NG_final_2ptunblind_02_26_21_wnz_maglim_covupdate.fits'))
bin1_vals =  df_cs['xip'].data['BIN1'][::20]
bin2_vals =  df_cs['xip'].data['BIN2'][::20]
biny_vals = np.array([1,2,3,4])

# index_gty = {}
index_gty = []
for js in range(80):
    # index_gty[js] = [js%20 ,js//20]
    index_gty.append([js%20 ,js//20])
index_gty = jnp.array(index_gty)
# index_xip = {}
index_xip = []
for js in range(200):
    binv = js//20
    thetav = js%20
    # index_xip[js] = [thetav ,bin1_vals[binv]-1, bin2_vals[binv]-1]
    index_xip.append([thetav ,bin1_vals[binv]-1, bin2_vals[binv]-1])
index_xip = jnp.array(index_xip)
# index_xim = {}
index_xim = []
for js in range(200):
    binv = js//20
    thetav = js%20
    # index_xim[js] = [thetav ,bin1_vals[binv]-1, bin2_vals[binv]-1]   
    index_xim.append([thetav ,bin1_vals[binv]-1, bin2_vals[binv]-1])
index_xim = jnp.array(index_xim)


prior_min_all_dict = {}
prior_max_all_dict = {}
prior_min_all_dict['Om0'] = 0.1
prior_max_all_dict['Om0'] = 0.5
prior_min_all_dict['Ob0'] = 0.03
prior_max_all_dict['Ob0'] = 0.07
prior_min_all_dict['h'] = 0.5
prior_max_all_dict['h'] = 0.9
prior_min_all_dict['ns'] = 0.8
prior_max_all_dict['ns'] = 1.2
prior_min_all_dict['sigma8'] = 0.6
prior_max_all_dict['sigma8'] = 1.0

prior_min_all_dict['theta_ej_0'] = 1.0
prior_max_all_dict['theta_ej_0'] = 5.0
prior_min_all_dict['log10_Mc0'] = 13.0
prior_max_all_dict['log10_Mc0'] = 15.0
prior_min_all_dict['nu_theta_ej_M'] = -3.0
prior_max_all_dict['nu_theta_ej_M'] = 0.0
prior_min_all_dict['nu_theta_ej_z'] = -2.0
prior_max_all_dict['nu_theta_ej_z'] = 2.0
prior_min_all_dict['alpha_nt'] = 0.0
prior_max_all_dict['alpha_nt'] = 0.4

prior_min_all_dict['A_IA'] = -3.0
prior_max_all_dict['A_IA'] = 3.0
prior_min_all_dict['eta_IA'] = -2.0
prior_max_all_dict['eta_IA'] = 2.0

prior_mu_all_dict = {}
prior_sig_all_dict = {}
prior_mu_all_dict['Delta_z_bias_bin1'] = 0.0
prior_sig_all_dict['Delta_z_bias_bin1'] = 1.8e-2
prior_mu_all_dict['Delta_z_bias_bin2'] = 0.0
prior_sig_all_dict['Delta_z_bias_bin2'] = 1.5e-2
prior_mu_all_dict['Delta_z_bias_bin3'] = 0.0
prior_sig_all_dict['Delta_z_bias_bin3'] = 1.1e-2
prior_mu_all_dict['Delta_z_bias_bin4'] = 0.0
prior_sig_all_dict['Delta_z_bias_bin4'] = 1.7e-2

prior_mu_all_dict['mult_shear_bias_bin1'] = -6e-3
prior_sig_all_dict['mult_shear_bias_bin1'] = 9e-3
prior_mu_all_dict['mult_shear_bias_bin2'] = -2e-2
prior_sig_all_dict['mult_shear_bias_bin2'] = 8e-3
prior_mu_all_dict['mult_shear_bias_bin3'] = -2.4e-2
prior_sig_all_dict['mult_shear_bias_bin3'] = 8e-3
prior_mu_all_dict['mult_shear_bias_bin4'] = -3.7e-2
prior_sig_all_dict['mult_shear_bias_bin4'] = 8e-3

prior_delta_z_mu_all = jnp.array([prior_mu_all_dict['Delta_z_bias_bin1'], prior_mu_all_dict['Delta_z_bias_bin2'], prior_mu_all_dict['Delta_z_bias_bin3'], prior_mu_all_dict['Delta_z_bias_bin4']])
prior_delta_z_sig_all = jnp.array([prior_sig_all_dict['Delta_z_bias_bin1'], prior_sig_all_dict['Delta_z_bias_bin2'], prior_sig_all_dict['Delta_z_bias_bin3'], prior_sig_all_dict['Delta_z_bias_bin4']])

prior_mult_shear_mu_all = jnp.array([prior_mu_all_dict['mult_shear_bias_bin1'], prior_mu_all_dict['mult_shear_bias_bin2'], prior_mu_all_dict['mult_shear_bias_bin3'], prior_mu_all_dict['mult_shear_bias_bin4']])
prior_mult_shear_sig_all = jnp.array([prior_sig_all_dict['mult_shear_bias_bin1'], prior_sig_all_dict['mult_shear_bias_bin2'], prior_sig_all_dict['mult_shear_bias_bin3'], prior_sig_all_dict['mult_shear_bias_bin4']])

# cosmo_params_vary_names = ['Om0', 'Ob0', 'H0', 'ns', 'sigma8']
# sims_params_vary_names = ['theta_ej_0','log10_Mc0', 'nu_theta_ej_M', 'nu_theta_ej_z', 'alpha_nt']
# IA_params_vary_names = ['A_IA', 'eta_IA']
# mult_shear_vary_names = ['mult_shear_bias_bin1', 'mult_shear_bias_bin2', 'mult_shear_bias_bin3', 'mult_shear_bias_bin4'] 
# Delta_shear_vary_names = ['Delta_z_bias_bin1', 'Delta_z_bias_bin2', 'Delta_z_bias_bin3', 'Delta_z_bias_bin4']

# 'H0': 67.2, 'Om0': 0.29, 'Ob0': 0.049, 'sigma8': 0.783, 'ns': 0.95
cosmo_params_vary_names = ['Om0', 'sigma8', 'Ob0', 'h', 'ns']
sims_params_vary_names = ['theta_ej_0', 'nu_theta_ej_M', 'nu_theta_ej_z']
# sims_params_vary_names = []
# cosmo_params_vary_names = []
IA_params_vary_names = ['A_IA', 'eta_IA']
# IA_params_vary_names = ['eta_IA']
# IA_params_vary_names = []

mult_shear_vary_names = ['mult_shear_bias_bin1', 'mult_shear_bias_bin2', 'mult_shear_bias_bin3', 'mult_shear_bias_bin4'] 
Delta_shear_vary_names = ['Delta_z_bias_bin1', 'Delta_z_bias_bin2', 'Delta_z_bias_bin3', 'Delta_z_bias_bin4']

# prior_delta_z_mu_all = []
# prior_delta_z_sig_all = []

# prior_mult_shear_mu_all = []
# prior_mult_shear_sig_all = []

# %%
from get_corr_func_jit import get_corrfunc_BCMP
import numpyro
import copy

def model():
    sim_params_dict_vary = copy.deepcopy(sim_params_dict)
    other_params_dict_vary = copy.deepcopy(other_params_dict)

    if len(cosmo_params_vary_names) > 0:
        for jp in range(len(cosmo_params_vary_names)):
            if cosmo_params_vary_names[jp] == 'h':
                fac = 100.
                cosmo_name = 'H0'
            else:
                fac = 1.
                cosmo_name = cosmo_params_vary_names[jp]
            prior_min_jp = prior_min_all_dict[cosmo_params_vary_names[jp]]
            prior_max_jp = prior_max_all_dict[cosmo_params_vary_names[jp]]
            sim_params_dict_vary['cosmo'][cosmo_name] = fac * Uniform(cosmo_params_vary_names[jp], prior_min_jp, prior_max_jp)

    if len(sims_params_vary_names) > 0:
        for jp in range(len(sims_params_vary_names)):
            prior_min_jp = prior_min_all_dict[sims_params_vary_names[jp]]
            prior_max_jp = prior_max_all_dict[sims_params_vary_names[jp]]
            sim_params_dict_vary[sims_params_vary_names[jp]] = Uniform(sims_params_vary_names[jp], prior_min_jp, prior_max_jp)
    
    if len(IA_params_vary_names) > 0:
        for jp in range(len(IA_params_vary_names)):
            prior_min_jp = prior_min_all_dict[IA_params_vary_names[jp]]
            prior_max_jp = prior_max_all_dict[IA_params_vary_names[jp]]
            other_params_dict_vary[IA_params_vary_names[jp]] = Uniform(IA_params_vary_names[jp], prior_min_jp, prior_max_jp)
        
    if len(prior_delta_z_mu_all) > 0:
        Delta_z_bias_array = numpyro.sample('Delta_z_bias_array', dist.Normal(prior_delta_z_mu_all, prior_delta_z_sig_all)) 
        other_params_dict_vary['Delta_z_bias_array'] = Delta_z_bias_array
    
    if len(prior_mult_shear_mu_all) > 0:
        mult_shear_bias_array = numpyro.sample('mult_shear_bias_array', dist.Normal(prior_mult_shear_mu_all, prior_mult_shear_sig_all))
        other_params_dict_vary['mult_shear_bias_array'] = mult_shear_bias_array
        
    
    get_corrfunc_BCMP_test = get_corrfunc_BCMP(sim_params_dict_vary, halo_params_dict, analysis_dict, other_params_dict_vary, verbose_time=False, num_points_trapz_int=32)

    def get_gty_from_index(index):
        index_val = index_gty[index]
        return get_corrfunc_BCMP_test.gty_out_mat[index_val[0], index_val[1]]

    def get_xip_from_index(index):
        index_val = index_xip[index]
        return get_corrfunc_BCMP_test.xip_out_mat[index_val[0], index_val[1], index_val[2]]

    def get_xim_from_index(index):
        index_val = index_xim[index]
        return get_corrfunc_BCMP_test.xim_out_mat[index_val[0], index_val[1], index_val[2]]

    gty_val = vmap(get_gty_from_index)(np.arange(80))
    xip_val = vmap(get_xip_from_index)(np.arange(200))
    xim_val = vmap(get_xim_from_index)(np.arange(200))

    if probe == 'xip_xim':
        mu = jnp.concatenate([xip_val, xim_val])
    elif probe == 'gty':
        mu = gty_val
    else:
        mu = jnp.concatenate([gty_val, xip_val, xim_val])
    # print(mu.shape, P_total.shape, cov_total.shape)
    return numpyro.sample('cl', dist.MultivariateNormal(mu, 
                                                        precision_matrix=P_total,
                                                        covariance_matrix=cov_total))



import numpyro
numpyro.set_host_device_count(4)
from numpyro.handlers import seed, trace, condition
# Now we condition the model on obervations
observed_model = condition(model, {'cl': data_vec})

import numpyro
from numpyro.infer.reparam import LocScaleReparam, TransformReparam

def config(x):
    if type(x['fn']) is dist.TransformedDistribution:
        return TransformReparam()
    elif type(x['fn']) is dist.Normal and ('decentered' not in x['name']):
        return LocScaleReparam(centered=0)
    else:
        return None

observed_model_reparam = numpyro.handlers.reparam(observed_model, config=config)


from numpyro.infer import HMC, HMCECS, MCMC, NUTS, SA, SVI, Trace_ELBO, init_to_value
nuts_kernel = numpyro.infer.NUTS(observed_model_reparam,
                            step_size=1e-1, 
                            init_strategy=numpyro.infer.init_to_median,
                            dense_mass=False,
                            max_tree_depth=4)

num_warmup = 500
num_samples=5000
num_chains=4
mcmc = numpyro.infer.MCMC(nuts_kernel, 
                          num_warmup=num_warmup, 
                          num_samples=num_samples,
                          num_chains=num_chains,
                          chain_method='vectorized',
                        #   chain_method='sequential',                          
                          progress_bar=True,
                          jit_model_args=True)

numpyro.set_platform("gpu")

import jax

mcmc.run(jax.random.PRNGKey(42))

s = mcmc.get_samples()
# saved = {'samples':s}
import pickle as pk
save_chain_dir = abs_path_results + '/chains/'
pk.dump(s, open(save_chain_dir + f'mcmc_probe_{probe}_deproj_{deproj}_{num_samples}_{num_warmup}_num_chains_{num_chains}.pkl', 'wb'))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 116
#     112 numpyro.set_platform("gpu")
#     114 import jax
# --> 116 mcmc.run(jax.random.PRNGKey(42))
#     118 s = mcmc.get_samples()
#     119 # saved = {'samples':s}
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/numpyro/infer/mcmc.py:653, in MCMC.run(self, rng_key, extra_fields, init_params, *args, **kwargs)
#     651 else:
#     652     assert self.chain_method == "vectorized"
# --> 653     states, last_state = partial_map_fn(map_args)
#     654     # swap num_samples x num_chains to num_chains x num_samples
#     655     states = tree_map(lambda x: jnp.swapaxes(x, 0, 1), states)
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/numpyro/infer/mcmc.py:426, in MCMC._single_chain_mcmc(self, init, args, kwargs, collect_fields)
#     424 # Check if _sample_fn is None, then we need to initialize the sampler.
#     425 if init_state is None or (getattr(self.sampler, "_sample_fn", None) is None):
# --> 426     new_init_state = self.sampler.init(
#     427         rng_key,
#     428         self.num_warmup,
#     429         init_params,
#     430         model_args=args,
#     431         model_kwargs=kwargs,
#     432     )
#     433     init_state = new_init_state if init_state is None else init_state
#     434 sample_fn, postprocess_fn = self._get_cached_fns()
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/numpyro/infer/hmc.py:743, in HMC.init(self, rng_key, num_warmup, init_params, model_args, model_kwargs)
#     738 # vectorized
#     739 else:
#     740     rng_key, rng_key_init_model = jnp.swapaxes(
#     741         vmap(random.split)(rng_key), 0, 1
#     742     )
# --> 743 init_params = self._init_state(
#     744     rng_key_init_model, model_args, model_kwargs, init_params
#     745 )
#     746 if self._potential_fn and init_params is None:
#     747     raise ValueError(
#     748         "Valid value of `init_params` must be provided with" " `potential_fn`."
#     749     )
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/numpyro/infer/hmc.py:687, in HMC._init_state(self, rng_key, model_args, model_kwargs, init_params)
#     680 def _init_state(self, rng_key, model_args, model_kwargs, init_params):
#     681     if self._model is not None:
#     682         (
#     683             new_init_params,
#     684             potential_fn,
#     685             postprocess_fn,
#     686             model_trace,
# --> 687         ) = initialize_model(
#     688             rng_key,
#     689             self._model,
#     690             dynamic_args=True,
#     691             init_strategy=self._init_strategy,
#     692             model_args=model_args,
#     693             model_kwargs=model_kwargs,
#     694             forward_mode_differentiation=self._forward_mode_differentiation,
#     695         )
#     696         if init_params is None:
#     697             init_params = new_init_params
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/numpyro/infer/util.py:656, in initialize_model(rng_key, model, init_strategy, dynamic_args, model_args, model_kwargs, forward_mode_differentiation, validate_grad)
#     646 model_kwargs = {} if model_kwargs is None else model_kwargs
#     647 substituted_model = substitute(
#     648     seed(model, rng_key if is_prng_key(rng_key) else rng_key[0]),
#     649     substitute_fn=init_strategy,
#     650 )
#     651 (
#     652     inv_transforms,
#     653     replay_model,
#     654     has_enumerate_support,
#     655     model_trace,
# --> 656 ) = _get_model_transforms(substituted_model, model_args, model_kwargs)
#     657 # substitute param sites from model_trace to model so
#     658 # we don't need to generate again parameters of `numpyro.module`
#     659 model = substitute(
#     660     model,
#     661     data={
#    (...)
#     665     },
#     666 )
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/numpyro/infer/util.py:450, in _get_model_transforms(model, model_args, model_kwargs)
#     448 def _get_model_transforms(model, model_args=(), model_kwargs=None):
#     449     model_kwargs = {} if model_kwargs is None else model_kwargs
# --> 450     model_trace = trace(model).get_trace(*model_args, **model_kwargs)
#     451     inv_transforms = {}
#     452     # model code may need to be replayed in the presence of deterministic sites
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/numpyro/handlers.py:171, in trace.get_trace(self, *args, **kwargs)
#     163 def get_trace(self, *args, **kwargs):
#     164     """
#     165     Run the wrapped callable and return the recorded trace.
#     166
#    (...)
#     169     :return: `OrderedDict` containing the execution trace.
#     170     """
# --> 171     self(*args, **kwargs)
#     172     return self.trace
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/numpyro/primitives.py:105, in Messenger.__call__(self, *args, **kwargs)
#     103     return self
#     104 with self:
# --> 105     return self.fn(*args, **kwargs)
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/numpyro/primitives.py:105, in Messenger.__call__(self, *args, **kwargs)
#     103     return self
#     104 with self:
# --> 105     return self.fn(*args, **kwargs)
#
#     [... skipping similar frames: Messenger.__call__ at line 105 (2 times)]
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/numpyro/primitives.py:105, in Messenger.__call__(self, *args, **kwargs)
#     103     return self
#     104 with self:
# --> 105     return self.fn(*args, **kwargs)
#
# Cell In[7], line 42, in model()
#      38     mult_shear_bias_array = numpyro.sample('mult_shear_bias_array', dist.Normal(prior_mult_shear_mu_all, prior_mult_shear_sig_all))
#      39     other_params_dict_vary['mult_shear_bias_array'] = mult_shear_bias_array
# ---> 42 get_corrfunc_BCMP_test = get_corrfunc_BCMP(sim_params_dict_vary, halo_params_dict, analysis_dict, other_params_dict_vary, verbose_time=False, num_points_trapz_int=32)
#      44 def get_gty_from_index(index):
#      45     index_val = index_gty[index]
#
# File /mnt/ceph/users/spandey/GODMAX/src/get_corr_func_jit.py:90, in get_corrfunc_BCMP.__init__(self, sim_params_dict, halo_params_dict, analysis_dict, other_params_dict, num_points_trapz_int, setup_power_BCMP_obj, get_power_BCMP_obj, verbose_time)
#      88         get_power_BCMP_obj = get_power_BCMP(sim_params_dict, halo_params_dict, analysis_dict, other_params_dict, num_points_trapz_int=num_points_trapz_int, setup_power_BCMP_obj=setup_power_BCMP_obj, verbose_time=verbose_time)
#      89     else:
# ---> 90         get_power_BCMP_obj = get_power_BCMP_NO_CONC(sim_params_dict, halo_params_dict, analysis_dict, other_params_dict, num_points_trapz_int=num_points_trapz_int, setup_power_BCMP_obj=setup_power_BCMP_obj, verbose_time=verbose_time)
#      91 if verbose_time:
#      92     print('Time for setup_power_BCMP: ', time.time() - ti)
#
# File /mnt/ceph/users/spandey/GODMAX/src/get_power_spectra_NO_CONC_jit.py:54, in get_power_BCMP_NO_CONC.__init__(self, sim_params_dict, halo_params_dict, analysis_dict, other_params_dict, num_points_trapz_int, setup_power_BCMP_obj, verbose_time)
#      52         setup_power_BCMP_obj = setup_power_BCMP(sim_params_dict, halo_params_dict, analysis_dict, num_points_trapz_int=num_points_trapz_int, verbose_time=verbose_time)
#      53     else:
# ---> 54         setup_power_BCMP_obj = setup_power_BCMP_NO_CONC(sim_params_dict, halo_params_dict, analysis_dict, num_points_trapz_int=num_points_trapz_int, verbose_time=verbose_time)
#      55 if verbose_time:
#      56     print('Time for setup_power_BCMP: ', time.time() - ti)
#
# File /mnt/ceph/users/spandey/GODMAX/src/setup_power_spectra_NO_CONC_jit.py:95, in setup_power_BCMP_NO_CONC.__init__(self, sim_params_dict, halo_params_dict, analysis_dict, num_points_trapz_int, BCMP_obj, verbose_time)
#      93     ti_pk = time.time()
#      94 self.kPk_array = jnp.logspace(jnp.log10(1E-3), jnp.log10(100), 64)
# ---> 95 self.plin_kz_mat = vmap(linear_matter_power,(None, None, 0))(self.cosmo_jax, self.kPk_array, self.scale_fac_a_array).T
#      96 if verbose_time:
#      97     tf_pk = time.time()
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/api.py:1268, in vmap.<locals>.vmap_f(*args, **kwargs)
#    1265 in_axes_flat = flatten_axes("vmap in_axes", in_tree, (in_axes, 0), kws=True)
#    1266 axis_size_ = (axis_size if axis_size is not None else
#    1267               _mapped_axis_size(fun, in_tree, args_flat, in_axes_flat, "vmap"))
# -> 1268 out_flat = batching.batch(
#    1269     flat_fun, axis_name, axis_size_, in_axes_flat,
#    1270     lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#    1271     spmd_axis_name=spmd_axis_name
#    1272 ).call_wrapped(*args_flat)
#    1273 return tree_unflatten(out_tree(), out_flat)
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/linear_util.py:192, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     189 gen = gen_static_args = out_store = None
#     191 try:
# --> 192   ans = self.f(*args, **dict(self.params, **kwargs))
#     193 except:
#     194   # Some transformations yield from inside context managers, so we have to
#     195   # interrupt them before reraising the exception. Otherwise they will only
#     196   # get garbage-collected at some later time, running their cleanup tasks
#     197   # only after this exception is handled, which can corrupt the global
#     198   # state.
#     199   while stack:
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax_cosmo/power.py:45, in linear_matter_power(cosmo, k, a, transfer_fn, **kwargs)
#      43 k = np.atleast_1d(k)
#      44 a = np.atleast_1d(a)
# ---> 45 g = bkgrd.growth_factor(cosmo, a)
#      46 t = transfer_fn(cosmo, k, **kwargs)
#      48 pknorm = cosmo.sigma8**2 / sigmasqr(cosmo, 8.0, transfer_fn, **kwargs)
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax_cosmo/background.py:398, in growth_factor(cosmo, a)
#     396     return _growth_factor_gamma(cosmo, a)
#     397 else:
# --> 398     return _growth_factor_ODE(cosmo, a)
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax_cosmo/background.py:478, in _growth_factor_ODE(cosmo, a, log10_amin, steps, eps)
#     475     return np.array([y[1], -q * y[1] + r * y[0]])
#     477 y0 = np.array([atab[0], 1.0])
# --> 478 y = odeint(D_derivs, y0, atab)
#     479 y1 = y[:, 0]
#     480 gtab = y1 / y1[-1]
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax_cosmo/scipy/ode.py:21, in odeint(fn, y0, t)
#      18     y = y + 1.0 / 6.0 * h * (k1 + 2 * k2 + 2 * k3 + k4)
#      19     return (y, t), y
# ---> 21 (yf, _), y = jax.lax.scan(rk4, (y0, np.array(t[0])), t)
#      22 return y
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/lax/control_flow/loops.py:281, in scan(f, init, xs, length, reverse, unroll)
#     279   in_flat = [*in_state, *in_carry, *in_ext]
#     280   num_carry += len(attrs_tracked)
# --> 281 out = scan_p.bind(*consts, *in_flat,
#     282                   reverse=reverse, length=length, jaxpr=jaxpr,
#     283                   num_consts=len(consts), num_carry=num_carry,
#     284                   linear=(False,) * (len(consts) + len(in_flat)),
#     285                   unroll=unroll)
#     286 if attrs_tracked:
#     287   out_state, out = split_list(out, [len(attrs_tracked)])
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/lax/control_flow/loops.py:1157, in scan_bind(*args, **params)
#    1155   _scan_typecheck(True, *in_atoms, **params)
#    1156   core.check_jaxpr(params['jaxpr'].jaxpr)
# -> 1157 return core.AxisPrimitive.bind(scan_p, *args, **params)
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/core.py:2727, in AxisPrimitive.bind(self, *args, **params)
#    2723 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2724                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2725 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2726              else axis_main.with_cur_sublevel())
# -> 2727 return self.bind_with_trace(top_trace, args, params)
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/core.py:423, in Primitive.bind_with_trace(self, trace, args, params)
#     422 def bind_with_trace(self, trace, args, params):
# --> 423   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     424   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/core.py:913, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     912 def process_primitive(self, primitive, tracers, params):
# --> 913   return primitive.impl(*tracers, **params)
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/dispatch.py:87, in apply_primitive(prim, *args, **params)
#      85 prev = lib.jax_jit.swap_thread_local_state_disable_jit(False)
#      86 try:
# ---> 87   outs = fun(*args)
#      88 finally:
#      89   lib.jax_jit.swap_thread_local_state_disable_jit(prev)
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/pjit.py:248, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     246 @api_boundary
#     247 def cache_miss(*args, **kwargs):
# --> 248   outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked = _python_pjit_helper(
#     249       fun, infer_params_fn, *args, **kwargs)
#     250   executable = _read_most_recent_pjit_call_executable(jaxpr)
#     251   maybe_fastpath_data = _get_fastpath_data(
#     252       executable, out_tree, args_flat, out_flat, attrs_tracked)
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/pjit.py:143, in _python_pjit_helper(fun, infer_params_fn, *args, **kwargs)
#     141   args_flat = [*init_states, *args_flat]
#     142 try:
# --> 143   out_flat = pjit_p.bind(*args_flat, **params)
#     144 except pxla.DeviceAssignmentMismatchError as e:
#     145   fails, = e.args
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/core.py:2727, in AxisPrimitive.bind(self, *args, **params)
#    2723 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2724                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2725 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2726              else axis_main.with_cur_sublevel())
# -> 2727 return self.bind_with_trace(top_trace, args, params)
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/core.py:423, in Primitive.bind_with_trace(self, trace, args, params)
#     422 def bind_with_trace(self, trace, args, params):
# --> 423   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     424   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/core.py:913, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     912 def process_primitive(self, primitive, tracers, params):
# --> 913   return primitive.impl(*tracers, **params)
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/pjit.py:1409, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1406 has_explicit_sharding = _pjit_explicit_sharding(
#    1407     in_shardings, out_shardings, None, None)
#    1408 if xla_extension_version >= 226:
# -> 1409   return xc._xla.pjit(
#    1410       name, f, call_impl_cache_miss, [], [], donated_argnums,
#    1411       tree_util.dispatch_registry,
#    1412       pxla.shard_arg if xla_extension_version >= 229 else pxla.temp_shard_arg,  # type: ignore
#    1413       _get_cpp_global_cache(has_explicit_sharding))(*args)
#    1414 else:
#    1415   return xc._xla.pjit(name, f, call_impl_cache_miss, [], [], donated_argnums,  # type: ignore
#    1416                       tree_util.dispatch_registry,
#    1417                       _get_cpp_global_cache(has_explicit_sharding))(*args)
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/pjit.py:1392, in _pjit_call_impl.<locals>.call_impl_cache_miss(*args_, **kwargs_)
#    1391 def call_impl_cache_miss(*args_, **kwargs_):
# -> 1392   out_flat, compiled = _pjit_call_impl_python(
#    1393       *args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1394       out_shardings=out_shardings, resource_env=resource_env,
#    1395       donated_invars=donated_invars, name=name, keep_unused=keep_unused,
#    1396       inline=inline)
#    1397   fastpath_data = _get_fastpath_data(
#    1398       compiled, tree_structure(out_flat), args, out_flat, [])
#    1399   return out_flat, fastpath_data
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/pjit.py:1325, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1319 global _most_recent_pjit_call_executable
#    1321 in_shardings = _resolve_in_shardings(
#    1322     args, in_shardings, out_shardings,
#    1323     resource_env.physical_mesh if resource_env is not None else None)
# -> 1325 compiled = _pjit_lower(
#    1326     jaxpr, in_shardings, out_shardings, resource_env,
#    1327     donated_invars, name, keep_unused, inline,
#    1328     lowering_parameters=mlir.LoweringParameters()).compile()
#    1329 _most_recent_pjit_call_executable.weak_key_dict[jaxpr] = compiled
#    1330 # This check is expensive so only do it if enable_checks is on.
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/pjit.py:1463, in _pjit_lower(jaxpr, in_shardings, out_shardings, *args, **kwargs)
#    1461 in_shardings = SameDeviceAssignmentTuple(tuple(in_shardings), da)
#    1462 out_shardings = SameDeviceAssignmentTuple(tuple(out_shardings), da)
# -> 1463 return _pjit_lower_cached(jaxpr, in_shardings, out_shardings, *args, **kwargs)
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/pjit.py:1511, in _pjit_lower_cached(jaxpr, sdat_in_shardings, sdat_out_shardings, resource_env, donated_invars, name, keep_unused, inline, lowering_parameters, in_layouts, out_layouts)
#    1505   return pxla.lower_mesh_computation(
#    1506     jaxpr, api_name, name, mesh,
#    1507     in_shardings, out_shardings, donated_invars,
#    1508     True, jaxpr.in_avals, tiling_method=None,
#    1509     lowering_parameters=lowering_parameters)
#    1510 else:
# -> 1511   return pxla.lower_sharding_computation(
#    1512       jaxpr, api_name, name, in_shardings, out_shardings,
#    1513       tuple(donated_invars), tuple(jaxpr.in_avals),
#    1514       keep_unused=keep_unused, inline=inline,
#    1515       devices_from_context=(
#    1516           None if mesh is None or mesh.empty else list(mesh.devices.flat)),
#    1517       lowering_parameters=lowering_parameters, in_layouts=in_layouts,
#    1518       out_layouts=out_layouts)
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/profiler.py:336, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     333 @wraps(func)
#     334 def wrapper(*args, **kwargs):
#     335   with TraceAnnotation(name, **decorator_kwargs):
# --> 336     return func(*args, **kwargs)
#     337   return wrapper
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:2038, in lower_sharding_computation(closed_jaxpr, api_name, fun_name, in_shardings, out_shardings, donated_invars, global_in_avals, keep_unused, inline, devices_from_context, lowering_parameters, in_layouts, out_layouts)
#    2034 semantic_out_shardings = SemanticallyEqualShardings(out_shardings)  # type: ignore
#    2035 prim_requires_devices = dispatch.jaxpr_has_prim_requiring_devices(jaxpr)
#    2037 (module, keepalive, host_callbacks, unordered_effects, ordered_effects,
# -> 2038  nreps, tuple_args, shape_poly_state) = _cached_lowering_to_hlo(
#    2039      closed_jaxpr, api_name, fun_name, backend, semantic_in_shardings,
#    2040      semantic_out_shardings, in_layouts, out_layouts, len(da_object),
#    2041      tuple(da_object) if prim_requires_devices else None, donated_invars,
#    2042      name_stack, all_default_mem_kind, lowering_parameters=lowering_parameters)
#    2044 # backend and device_assignment is passed through to MeshExecutable because
#    2045 # if keep_unused=False and all in_shardings are pruned, then there is no way
#    2046 # to get the device_assignment and backend. So pass it to MeshExecutable
#    2047 # because we calculate the device_assignment and backend before in_shardings,
#    2048 # etc are pruned.
#    2049 return MeshComputation(
#    2050     str(name_stack),
#    2051     module,
#    (...)
#    2072     all_default_mem_kind=all_default_mem_kind,
#    2073     all_args_info=all_args_info)
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:1879, in _cached_lowering_to_hlo(closed_jaxpr, api_name, fun_name, backend, semantic_in_shardings, semantic_out_shardings, in_layouts, out_layouts, num_devices, device_assignment, donated_invars, name_stack, all_default_mem_kind, lowering_parameters)
#    1874 ordered_effects = list(effects.ordered_effects.filter_in(closed_jaxpr.effects))
#    1876 with dispatch.log_elapsed_time(
#    1877       "Finished jaxpr to MLIR module conversion {fun_name} in {elapsed_time} sec",
#    1878       fun_name=str(name_stack), event=dispatch.JAXPR_TO_MLIR_MODULE_EVENT):
# -> 1879   lowering_result = mlir.lower_jaxpr_to_module(
#    1880       module_name,
#    1881       closed_jaxpr,
#    1882       ordered_effects=ordered_effects,
#    1883       backend_or_name=backend,
#    1884       # Optionally, override the lowering platform
#    1885       platforms=lowering_parameters.platforms or (backend.platform,),
#    1886       axis_context=axis_ctx,
#    1887       name_stack=name_stack,
#    1888       donated_args=donated_invars,
#    1889       replicated_args=replicated_args,
#    1890       arg_shardings=in_mlir_shardings,
#    1891       result_shardings=out_mlir_shardings,
#    1892       in_layouts=in_layouts,
#    1893       out_layouts=out_layouts,
#    1894       arg_names=jaxpr.debug_info and jaxpr.debug_info.arg_names,
#    1895       result_names=jaxpr.debug_info and jaxpr.debug_info.result_paths,
#    1896       num_replicas=nreps,
#    1897       num_partitions=num_partitions,
#    1898       all_default_mem_kind=all_default_mem_kind,
#    1899       lowering_parameters=lowering_parameters)
#    1900 tuple_args = dispatch.should_tuple_args(len(global_in_avals), backend.platform)
#    1901 unordered_effects = list(
#    1902     effects.ordered_effects.filter_not_in(closed_jaxpr.effects))
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:970, in lower_jaxpr_to_module(***failed resolving arguments***)
#     968   attrs["mhlo.num_partitions"] = i32_attr(num_partitions)
#     969   replace_tokens_with_dummy = lowering_parameters.replace_tokens_with_dummy
# --> 970   lower_jaxpr_to_fun(
#     971       ctx, "main", jaxpr, ordered_effects,
#     972       name_stack=name_stack,
#     973       public=True,
#     974       create_tokens=replace_tokens_with_dummy,
#     975       replace_tokens_with_dummy=replace_tokens_with_dummy,
#     976       num_output_tokens=0,
#     977       replicated_args=replicated_args,
#     978       arg_shardings=arg_op_shardings,
#     979       result_shardings=result_op_shardings,
#     980       input_output_aliases=input_output_aliases,
#     981       xla_donated_args=xla_donated_args,
#     982       arg_names=arg_names,
#     983       result_names=result_names,
#     984       arg_memory_kinds=arg_memory_kinds,
#     985       result_memory_kinds=result_memory_kinds,
#     986       arg_layouts=arg_layouts,
#     987       result_layouts=result_layouts)
#     989 try:
#     990   if not ctx.module.operation.verify():
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:1415, in lower_jaxpr_to_fun(ctx, name, jaxpr, effects, name_stack, create_tokens, public, replace_tokens_with_dummy, replicated_args, arg_shardings, result_shardings, use_sharding_annotations, input_output_aliases, xla_donated_args, num_output_tokens, api_name, arg_names, result_names, arg_memory_kinds, result_memory_kinds, arg_layouts, result_layouts)
#    1413 callee_name_stack = name_stack.extend(util.wrap_name(name, api_name))
#    1414 consts = [ir_constants(xla.canonicalize_dtype(x)) for x in jaxpr.consts]
# -> 1415 out_vals, tokens_out = jaxpr_subcomp(
#    1416     ctx, jaxpr.jaxpr, callee_name_stack, tokens_in,
#    1417     consts, *args, dim_var_values=dim_var_values)
#    1418 outs = []
#    1419 if create_tokens:
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:1596, in jaxpr_subcomp(ctx, jaxpr, name_stack, tokens, consts, dim_var_values, *args)
#    1593   rule_ctx = rule_ctx.replace(axis_size_env=axis_size_env)
#    1595 rule_inputs = map(_unwrap_singleton_ir_values, in_nodes)
# -> 1596 ans = lower_per_platform(rule_ctx, str(eqn.primitive),
#    1597                          platform_rules, default_rule,
#    1598                          eqn.effects,
#    1599                          *rule_inputs, **eqn.params)
#    1601 if effects:
#    1602   # If there were ordered effects in the primitive, there should be output
#    1603   # tokens we need for subsequent ordered effects.
#    1604   tokens_out = rule_ctx.tokens_out
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:1704, in lower_per_platform(ctx, description, platform_rules, default_rule, effects, *rule_args, **rule_kwargs)
#    1702 # If there is a single rule left just apply the rule, without conditionals.
#    1703 if len(kept_rules) == 1:
# -> 1704  return kept_rules[0](ctx, *rule_args, **rule_kwargs)
#    1706 assert len(platforms) > 1 and len(kept_rules) >= 2, (platforms, kept_rules)
#    1707 assert len(ctx.dim_var_values) >= 1, "Must have a platform_index variable"
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:1788, in lower_fun.<locals>.f_lowered(ctx, *args, **params)
#    1786   jaxpr, _, consts = pe.trace_to_jaxpr_dynamic2(wrapped_fun)
#    1787 else:
# -> 1788   jaxpr, _, consts, () = pe.trace_to_jaxpr_dynamic(wrapped_fun, ctx.avals_in)
#    1789   # TODO(frostig,mattjj): check ctx.avals_out against jaxpr avals out?
#    1791 out, tokens = jaxpr_subcomp(
#    1792     ctx.module_context, jaxpr, ctx.name_stack, ctx.tokens_in,
#    1793     _ir_consts(consts), *map(wrap_singleton_ir_values, args),
#    1794     dim_var_values=ctx.dim_var_values)
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/profiler.py:336, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     333 @wraps(func)
#     334 def wrapper(*args, **kwargs):
#     335   with TraceAnnotation(name, **decorator_kwargs):
# --> 336     return func(*args, **kwargs)
#     337   return wrapper
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:2314, in trace_to_jaxpr_dynamic(fun, in_avals, debug_info, keep_inputs)
#    2312 with core.new_main(DynamicJaxprTrace, dynamic=True) as main:  # type: ignore
#    2313   main.jaxpr_stack = ()  # type: ignore
# -> 2314   jaxpr, out_avals, consts, attrs_tracked = trace_to_subjaxpr_dynamic(
#    2315     fun, main, in_avals, keep_inputs=keep_inputs, debug_info=debug_info)
#    2316   del main, fun
#    2317 return jaxpr, out_avals, consts, attrs_tracked
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:2336, in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs, debug_info)
#    2334 in_tracers = _input_type_to_tracers(trace.new_arg, in_avals)
#    2335 in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 2336 ans = fun.call_wrapped(*in_tracers_)
#    2337 out_tracers = map(trace.full_raise, ans)
#    2338 jaxpr, consts, attrs_tracked = frame.to_jaxpr(out_tracers)
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/linear_util.py:192, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     189 gen = gen_static_args = out_store = None
#     191 try:
# --> 192   ans = self.f(*args, **dict(self.params, **kwargs))
#     193 except:
#     194   # Some transformations yield from inside context managers, so we have to
#     195   # interrupt them before reraising the exception. Otherwise they will only
#     196   # get garbage-collected at some later time, running their cleanup tasks
#     197   # only after this exception is handled, which can corrupt the global
#     198   # state.
#     199   while stack:
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/lax/control_flow/loops.py:452, in _scan_impl(reverse, length, num_consts, num_carry, jaxpr, linear, unroll, *args)
#     449 f_impl = core.jaxpr_as_fun(jaxpr)
#     451 if unroll == 1:
# --> 452   return _scan_impl_loop(
#     453       *args, reverse=reverse, length=length, num_consts=num_consts,
#     454       num_carry=num_carry, linear=linear, f_impl=f_impl, x_avals=x_avals,
#     455       y_avals=y_avals)
#     457 consts, init, xs = split_list(args, [num_consts, num_carry])
#     458 num_blocks, rem = divmod(length, unroll)
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/lax/control_flow/loops.py:413, in _scan_impl_loop(reverse, length, num_consts, num_carry, linear, f_impl, x_avals, y_avals, *args)
#     411 else:
#     412   init_val = [lax._const(length, 0)] + init + ys_init
# --> 413   _, *outs = while_loop(cond_fun, body_fun, init_val)
#     414   return outs
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/lax/control_flow/loops.py:1270, in while_loop(cond_fun, body_fun, init_val)
#    1263   return init_vals, init_avals, body_jaxpr, in_tree, cond_jaxpr, cond_consts, body_consts, body_tree
#    1265 # The body input and output avals must match exactly. However, we want to account for
#    1266 # the case when init contains weakly-typed values (e.g. Python scalars), with avals that
#    1267 # may not match the output despite being compatible by virtue of their weak type.
#    1268 # To do this, we compute the jaxpr in two passes: first with the raw inputs, and if
#    1269 # necessary, a second time with modified init values.
# -> 1270 init_vals, init_avals, body_jaxpr, in_tree, *rest = _create_jaxpr(init_val)
#    1271 new_init_vals, changed = _promote_weak_typed_inputs(init_vals, init_avals, body_jaxpr.out_avals)
#    1272 if changed:
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/lax/control_flow/loops.py:1253, in while_loop.<locals>._create_jaxpr(init_val)
#    1250 init_avals = tuple(_map(_abstractify, init_vals))
#    1251 cond_jaxpr, cond_consts, cond_tree = _initial_style_jaxpr(
#    1252     cond_fun, in_tree, init_avals, "while_cond")
# -> 1253 body_jaxpr, body_consts, body_tree = _initial_style_jaxpr(
#    1254     body_fun, in_tree, init_avals, "while_loop")
#    1255 if not treedef_is_leaf(cond_tree) or len(cond_jaxpr.out_avals) != 1:
#    1256   msg = "cond_fun must return a boolean scalar, but got pytree {}."
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/lax/control_flow/common.py:67, in _initial_style_jaxpr(fun, in_tree, in_avals, primitive_name)
#      64 @weakref_lru_cache
#      65 def _initial_style_jaxpr(fun: Callable, in_tree, in_avals,
#      66                          primitive_name: str | None = None):
# ---> 67   jaxpr, consts, out_tree, () = _initial_style_open_jaxpr(
#      68       fun, in_tree, in_avals, primitive_name)
#      69   closed_jaxpr = pe.close_jaxpr(pe.convert_constvars_jaxpr(jaxpr))
#      70   return closed_jaxpr, consts, out_tree
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/lax/control_flow/common.py:60, in _initial_style_open_jaxpr(fun, in_tree, in_avals, primitive_name)
#      57 wrapped_fun, out_tree = flatten_fun_nokwargs(lu.wrap_init(fun), in_tree)
#      58 debug = pe.debug_info(fun, in_tree, out_tree, False,
#      59                       primitive_name or "<unknown>")
# ---> 60 jaxpr, _, consts, attrs_tracked = pe.trace_to_jaxpr_dynamic(
#      61     wrapped_fun, in_avals, debug)
#      62 return jaxpr, consts, out_tree(), attrs_tracked
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/profiler.py:336, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     333 @wraps(func)
#     334 def wrapper(*args, **kwargs):
#     335   with TraceAnnotation(name, **decorator_kwargs):
# --> 336     return func(*args, **kwargs)
#     337   return wrapper
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:2314, in trace_to_jaxpr_dynamic(fun, in_avals, debug_info, keep_inputs)
#    2312 with core.new_main(DynamicJaxprTrace, dynamic=True) as main:  # type: ignore
#    2313   main.jaxpr_stack = ()  # type: ignore
# -> 2314   jaxpr, out_avals, consts, attrs_tracked = trace_to_subjaxpr_dynamic(
#    2315     fun, main, in_avals, keep_inputs=keep_inputs, debug_info=debug_info)
#    2316   del main, fun
#    2317 return jaxpr, out_avals, consts, attrs_tracked
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:2336, in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs, debug_info)
#    2334 in_tracers = _input_type_to_tracers(trace.new_arg, in_avals)
#    2335 in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 2336 ans = fun.call_wrapped(*in_tracers_)
#    2337 out_tracers = map(trace.full_raise, ans)
#    2338 jaxpr, consts, attrs_tracked = frame.to_jaxpr(out_tracers)
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/linear_util.py:192, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     189 gen = gen_static_args = out_store = None
#     191 try:
# --> 192   ans = self.f(*args, **dict(self.params, **kwargs))
#     193 except:
#     194   # Some transformations yield from inside context managers, so we have to
#     195   # interrupt them before reraising the exception. Otherwise they will only
#     196   # get garbage-collected at some later time, running their cleanup tasks
#     197   # only after this exception is handled, which can corrupt the global
#     198   # state.
#     199   while stack:
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/lax/control_flow/loops.py:401, in _scan_impl_loop.<locals>.body_fun(vals)
#     399 xs_unconsumed =  _map(key_reuse.reuse_key, xs)
#     400 x = _map(partial(_dynamic_index_array, i_), x_avals, xs_unconsumed)
# --> 401 out_flat = f_impl(*consts, *carry, *x)
#     402 carry_out, y_updates = split_list(out_flat, [num_carry])
#     403 ys_out = _map(partial(_update_array, i_), y_avals, ys, y_updates)
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/core.py:292, in jaxpr_as_fun(closed_jaxpr, *args)
#     290 @curry
#     291 def jaxpr_as_fun(closed_jaxpr: ClosedJaxpr, *args):
# --> 292   return eval_jaxpr(closed_jaxpr.jaxpr, closed_jaxpr.consts, *args)
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/site-packages/jax/_src/core.py:487, in eval_jaxpr(jaxpr, consts, propagate_source_info, *args)
#     485 name_stack = source_info_util.current_name_stack() + eqn.source_info.name_stack
#     486 traceback = eqn.source_info.traceback if propagate_source_info else None
# --> 487 with source_info_util.user_context(traceback, name_stack=name_stack):
#     488   ans = eqn.primitive.bind(*subfuns, *map(read, eqn.invars), **bind_params)
#     489 if eqn.primitive.multiple_results:
#
# File ~/miniconda3/envs/ili-sbi/lib/python3.10/contextlib.py:279, in contextmanager.<locals>.helper(*args, **kwds)
#     252 def contextmanager(func):
#     253     """@contextmanager decorator.
#     254
#     255     Typical usage:
#    (...)
#     277             <cleanup>
#     278     """
# --> 279     @wraps(func)
#     280     def helper(*args, **kwds):
#     281         return _GeneratorContextManager(func, args, kwds)
#     282     return helper
#
# KeyboardInterrupt:

# %%
# !pip install jax_cosmo
# Out:
# /mnt/home/spandey/miniconda3/envs/ili-sbi/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Requirement already satisfied: jax_cosmo in /mnt/home/spandey/miniconda3/envs/ili-sbi/lib/python3.10/site-packages (0.1.0)
# Requirement already satisfied: jax in /mnt/home/spandey/miniconda3/envs/ili-sbi/lib/python3.10/site-packages (from jax_cosmo) (0.4.25)
# Requirement already satisfied: jaxlib in /mnt/home/spandey/miniconda3/envs/ili-sbi/lib/python3.10/site-packages (from jax_cosmo) (0.4.25+cuda11.cudnn86)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /mnt/home/spandey/miniconda3/envs/ili-sbi/lib/python3.10/site-packages (from jax->jax_cosmo) (0.3.2)
# Requirement already satisfied: numpy>=1.22 in /mnt/home/spandey/miniconda3/envs/ili-sbi/lib/python3.10/site-packages (from jax->jax_cosmo) (1.26.4)
# Requirement already satisfied: opt-einsum in /mnt/home/spandey/miniconda3/envs/ili-sbi/lib/python3.10/site-packages (from jax->jax_cosmo) (3.3.0)
# Requirement already satisfied: scipy>=1.9 in /mnt/home/spandey/miniconda3/envs/ili-sbi/lib/python3.10/site-packages (from jax->jax_cosmo) (1.12.0)
